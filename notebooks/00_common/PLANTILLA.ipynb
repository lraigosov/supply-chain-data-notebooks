# %% [markdown]
# # PLANTILLA · Notebook
#
#
# ## 🎯 Objetivos de Aprendizaje
# - [ ] Definir qué aprenderá el lector (máx. 5–7 puntos).
# - [ ] Conectar con el caso de uso del dominio (p. ej., demanda, logística, IoT).
# - [ ] Incluir resultados verificables (métricas, validaciones, artefactos generados).
#
# ## 🧩 Prerrequisitos
# - [ ] Versión de Python y paquetes clave (p. ej., `pandas`, `pyarrow`, `statsmodels`, `plotly`).
# - [ ] Datasets necesarios (ruta relativa en `data/raw/` o `data/processed/`).
# - [ ] Configuración previa (entorno, credenciales si aplica).
#
# ## 🗃️ Datasets
# - [ ] Describir cada dataset con campos principales y tamaño aproximado.
# - [ ] Indicar si se derivan/limpian en `curated` o `analytics`.
#
# ## 🧠 Caso de Uso
# - [ ] Contexto de negocio (problema, objetivo).
# - [ ] Decisiones habilitadas por el análisis/modelo.
# - [ ] KPIs o métricas relevantes.
#
# ## 🧭 Estructura del Notebook
# 1. Setup y carga de datos
# 2. Análisis/Modelado (bloques con títulos claros)
# 3. Validaciones y resultados
# 4. Exportación de artefactos (parquet/csv/gráficos)
# 5. Conclusiones
# 6. Notas de operación (costes, retención, gobernanza)
#
# ## 🛠️ Notas de Operación (Costes, Retención, Gobernanza)
# - Costes: indicar consideraciones de almacenamiento/cómputo/visualización.
# - Retención: política por zonas (`raw`, `curated`, `analytics`) y ventanas temporales.
# - Gobernanza: calidad de datos, seguridad/PII, linaje, versionado de modelos/artefactos.
#
# ## 🔗 Referencias
# - Enlaces a documentación interna/externa, papers, guías técnicas.
#
# > Usa esta plantilla como punto de partida. Mantén las secciones concisas, accionables y verificables; acompaña cada bloque de código con una breve explicación.

# %%
# ⚙️ Preparación de entorno y rutas
# Si esta celda tarda demasiado o se cuelga:
# 1) Abre la paleta de comandos (Ctrl+Shift+P)
# 2) "Jupyter: Restart Kernel"
# 3) "Run All Above/Below" o ejecuta desde la primera celda

import sys
from pathlib import Path

# Detectar raíz del repo (buscando pyproject.toml o carpeta src)
_candidates = [Path.cwd(), *Path.cwd().parents]
_repo_root = None
for _p in _candidates:
    if (_p / 'pyproject.toml').exists() or (_p / 'src').exists():
        _repo_root = _p
        break
if _repo_root is None:
    _repo_root = Path.cwd()

if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

print(f"✅ Entorno listo. Raíz del repo: {_repo_root}")

# %% [markdown]
# # Qué / Por qué / Para qué / Cuándo / Cómo
# - **Qué:** Describir brevemente el objetivo del cuaderno.
# - **Por qué:** Justificar el valor para el negocio.
# - **Para qué:** Decisiones o entregables que habilita.
# - **Cuándo:** Contexto temporal/proceso donde aplica.
# - **Cómo:** Enfoque, datos y herramientas utilizadas.

# %% [markdown]
# ## Setup de entorno
# Importar librerías, configurar opciones y rutas (usar src/utils si aplica).

# %%
import os, sys, platform
import numpy as np
import pandas as pd
np.random.seed(42)
print(f'Python: {platform.python_version()} | pandas: {pd.__version__}')

# %% [markdown]
# ## Carga de datos
# Leer datasets necesarios desde data/raw o fuentes externas y validar esquemas.

# %%
from pathlib import Path
DATA_PATH = Path('data/raw')
# df = pd.read_csv(DATA_PATH / 'archivo.csv')
# display(df.head())

# %% [markdown]
# ## Desarrollo / Análisis / Modelo
# Escribir la lógica principal: transformaciones, análisis, modelado o visualización.

# %%
# TODO: implementar pasos principales
# ...

# %% [markdown]
# ## Resultados y hallazgos
# Resumir métricas y visualizaciones clave; exportar resultados si corresponde.

# %%
# TODO: generar outputs
# ...

# %% [markdown]
# ## Próximos pasos
# - Hipótesis y mejoras a evaluar.
# - Tareas de producción o integración.

# %% [markdown]
# <div style="width: 100%; margin: 24px 0; border-top: 1px solid #eaecef; padding-top: 24px;">
#
#   <div style="display: flex; justify-content: space-between; align-items: center; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif;">
#
#     <!-- Previous Link -->
#     <div style="flex: 1; text-align: left;">
#       <span style="color: #6a737d; font-size: 14px; cursor: default;">
#   ← Anterior
# </span>
#     </div>
#
#     <!-- Central Links -->
#     <div style="flex: 1; text-align: center; font-size: 14px;">
#       <a href="../../README.md" style="color: #0366d6; text-decoration: none; font-weight: 600; margin: 0 10px;">📑 Índice</a>
#       <span style="color: #6a737d;">|</span>
#       <a href="../../config/notebooks_index.yml" style="color: #0366d6; text-decoration: none; font-weight: 600; margin: 0 10px;">📋 Catálogo</a>
#     </div>
#
#     <!-- Next Link -->
#     <div style="flex: 1; text-align: right;">
#         <span style="color: #6a737d; font-size: 14px; cursor: default;">
#   Siguiente →
# </span>
#     </div>
#
#   </div>
# </div>
