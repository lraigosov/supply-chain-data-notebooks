# %%
# ⚙️ Preparación de entorno y rutas
# Si esta celda tarda demasiado o se cuelga:
# 1) Abre la paleta de comandos (Ctrl+Shift+P)
# 2) "Jupyter: Restart Kernel"
# 3) "Run All Above/Below" o ejecuta desde la primera celda

import sys
from pathlib import Path

# Detectar raíz del repo (buscando pyproject.toml o carpeta src)
_candidates = [Path.cwd(), *Path.cwd().parents]
_repo_root = None
for _p in _candidates:
    if (_p / 'pyproject.toml').exists() or (_p / 'src').exists():
        _repo_root = _p
        break
if _repo_root is None:
    _repo_root = Path.cwd()

if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

print(f"✅ Entorno listo. Raíz del repo: {_repo_root}")

# %% [markdown]
# # Qué / Por qué / Para qué / Cuándo / Cómo
# - **Qué:** Describir brevemente el objetivo del cuaderno.
# - **Por qué:** Justificar el valor para el negocio.
# - **Para qué:** Decisiones o entregables que habilita.
# - **Cuándo:** Contexto temporal/proceso donde aplica.
# - **Cómo:** Enfoque, datos y herramientas utilizadas.

# %% [markdown]
# ## Setup de entorno
# Importar librerías, configurar opciones y rutas (usar src/utils si aplica).

# %%
import os, sys, platform
import numpy as np
import pandas as pd
np.random.seed(42)
print(f'Python: {platform.python_version()} | pandas: {pd.__version__}')

# %% [markdown]
# ## Carga de datos
# Leer datasets necesarios desde data/raw o fuentes externas y validar esquemas.

# %%
from pathlib import Path
DATA_PATH = Path('data/raw')
# df = pd.read_csv(DATA_PATH / 'archivo.csv')
# display(df.head())

# %% [markdown]
# ## Desarrollo / Análisis / Modelo
# Escribir la lógica principal: transformaciones, análisis, modelado o visualización.

# %%
# TODO: implementar pasos principales
# ...

# %% [markdown]
# ## Resultados y hallazgos
# Resumir métricas y visualizaciones clave; exportar resultados si corresponde.

# %%
# TODO: generar outputs
# ...

# %% [markdown]
# ## Próximos pasos
# - Hipótesis y mejoras a evaluar.
# - Tareas de producción o integración.
