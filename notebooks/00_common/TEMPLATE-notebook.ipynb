# %% [markdown]
# # [ID]: [Título del Notebook]
#
#
#
# ## 📋 Contexto del Caso de Negocio
#
# **Empresa:** "[Nombre Empresa]" - [Descripción breve del tipo de empresa y contexto].
#
# **Situación actual:**
# - [Métrica/KPI actual]: [valor actual]
# - **Problema:** [Descripción del problema principal a resolver]
# - Factores relevantes:
#   - [Factor 1]
#   - [Factor 2]
#   - [Factor 3]
#
# **Impacto financiero:**
# - [Impacto 1 cuantificado]
# - [Impacto 2 cuantificado]
# - [Impacto 3 cuantificado]
#
# **Objetivo:** Implementar [solución/modelo/análisis] para:
# 1. [Objetivo específico 1]
# 2. [Objetivo específico 2]
# 3. [Objetivo específico 3]
# 4. [Objetivo específico 4]
#
# ### 💼 ¿Por qué es IMPORTANTE?
# - **[Razón 1]:** [Descripción]
# - **[Razón 2]:** [Descripción]
# - **[Razón 3]:** [Descripción]
# - **[Razón 4]:** [Descripción]
#
# ### 🎁 ¿PARA QUÉ sirve?
# - **[Uso 1]:** [Descripción]
# - **[Uso 2]:** [Descripción]
# - **[Uso 3]:** [Descripción]
# - **[Uso 4]:** [Descripción]
#
# ### 🔧 ¿CÓMO se implementa?
# - **Datos requeridos:** [Lista de datasets necesarios]
# - **Cálculo principal:** `[Fórmula o lógica principal]`
# - **Métrica resultado:** `[Fórmula de métrica resultado]`
# - **Técnica aplicada:** [Técnica/metodología/algoritmo]
#
# ---

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# - [Objetivo de aprendizaje 1 - verbo en infinitivo]
# - [Objetivo de aprendizaje 2 - verbo en infinitivo]
# - [Objetivo de aprendizaje 3 - verbo en infinitivo]

# %% [markdown]
# ## 📦 Instalación de Librerías Necesarias
#
# **Antes de ejecutar este notebook, asegúrate de tener instaladas todas las dependencias.**
#
# ### Opción 1: Instalación dentro del notebook
# Ejecuta la siguiente celda para instalar las librerías necesarias:
#
# ```python
# %pip install [librería1] [librería2] [librería3]
# ```
#
# ### Opción 2: Instalación desde terminal
# Si prefieres instalar desde la terminal, ejecuta:
#
# ```bash
# # PowerShell o CMD
# pip install [librería1] [librería2] [librería3]
#
# # O si usas el proyecto completo con pyproject.toml
# pip install -e .[core,notebooks]
# ```
#
# ### Librerías requeridas:
# - `pandas`: Manipulación y análisis de datos
# - `numpy`: Cálculos numéricos y arrays
# - `matplotlib`: Visualización estática
# - `seaborn`: Visualización estadística avanzada
# - `[otra_librería]`: [Descripción de uso]
#
# ---

# %% [markdown]
# ### 📝 Información del Notebook
#
# | Campo | Valor |
# | :--- | :--- |
# | **🆔 ID** | `[XX-##]` |
# | **📛 Título** | `[Título descriptivo]` |
# | **🔹 Especialidad** | `[Data Engineering / Data Science / Business Analytics / Optimization / etc.]` |
# | **⚙️ Proceso** | `[Plan / Source / Make / Deliver / Return]` |
# | **🧠 Nivel** | `[Basic / Intermediate / Advanced]` |
# | **⏱️ Duración** | `[XX min]` |
# | **🏷️ Etiquetas** | `[tag1]`, `[tag2]`, `[tag3]` |

# %% [markdown]
# ---
#
# ## ⚙️ Configuración Inicial

# %% [markdown]
# ## 🎯 Contexto del Notebook
#
# ### ¿Qué?
# [Descripción clara y concisa de QUÉ se implementa en este notebook]
#
# ### ¿Por qué?
# [Explicación del problema o situación que motiva este análisis/implementación]
#
# ### ¿Para qué?
# [Lista de beneficios o resultados esperados - por qué importa]
# - [Beneficio 1]
# - [Beneficio 2]
# - [Beneficio 3]
#
# ### ¿Cuándo?
# [Cuándo ejecutar este notebook - horarios, triggers, frecuencia]
#
# ### ¿Cómo?
# [Pasos de alto nivel de lo que se hará]
# 1. [Paso 1]
# 2. [Paso 2]
# 3. [Paso 3]
# 4. [Paso 4]

# %%
# ⚙️ Configuración de rutas
import sys
from pathlib import Path

def resolve_repo_root():
    """Detecta raíz del repositorio buscando carpetas data/ y notebooks/"""
    current = Path.cwd()
    for parent in [current, *current.parents]:
        if (parent / 'data').exists() and (parent / 'notebooks').exists():
            return parent
    return current

root = resolve_repo_root()
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

print(f"✅ Rutas configuradas: {root}")

# %%
# 📚 Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Configuración de visualización
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# [Importar librerías adicionales según el caso]
# from sklearn.xxx import xxx

print("✅ Librerías cargadas")

# %% [markdown]
# ---
#
# # 🔧 PASOS DEL NOTEBOOK
#
# > **NOTA:** Los pasos a continuación son **ejemplos de estructura**. Cada notebook puede tener diferente número de pasos según su complejidad. Lo importante es mantener el patrón:
# >
# > 1. **Celda Markdown:** Título del paso + explicación técnica/conceptos
# > 2. **Celda Código:** Implementación
#
# ---
#
# ## [Emoji] Paso N: [Nombre descriptivo del paso]
#
# [Explicación técnica del paso - puede incluir:]
# - **Concepto:** [Explicación del concepto/técnica aplicada]
# - **Fórmula:** `[fórmula si aplica]`
# - **Parámetros:** [Descripción de parámetros clave]
# - **Supuestos:** [Supuestos o limitaciones]

# %%
# [Implementación del paso]
# [Código comentado con mejores prácticas]

print("✅ Paso N completado")

# %% [markdown]
# ---
#
# ## 📊 Ejemplo - Paso 1: Cargar y preparar datos
#
# **Técnica:** Ingesta de datos desde fuentes raw (CSV, Parquet, DB)
#
# **Parámetros clave:**
# - `parse_dates`: Columnas a convertir a datetime
# - `dtype`: Forzar tipos de datos específicos
# - `encoding`: Codificación del archivo (utf-8, latin-1)

# %%
# Cargar datasets
# df = pd.read_csv(root / 'data' / 'raw' / '[archivo].csv', parse_dates=['[fecha_col]'])

print(f"📦 Datos cargados:")
# print(f"  Registros: {len(df):,}")
# print(f"  Columnas: {list(df.columns)}")

# %% [markdown]
# ---
#
# ## 🔄 Ejemplo - Paso 2: Transformación
#
# **Técnica:** Enriquecimiento, cálculos derivados, joins
#
# **Fórmulas:**
# - `nueva_col = col1 × factor + col2`
#
# **Parámetros de negocio:**
# - `PARAMETRO_1`: [Descripción y valor por defecto]

# %%
# Transformaciones
# df['nueva_columna'] = df['col1'] * PARAMETRO_1

print("🔄 Transformaciones aplicadas")

# %% [markdown]
# ---
#
# ## 📈 Ejemplo - Paso N: Visualización
#
# **Tipo de gráfico:** [Bar / Line / Scatter / Heatmap / etc.]
#
# **Objetivo:** [Qué insight se busca mostrar]

# %%
# Visualización
# fig, ax = plt.subplots(figsize=(12, 6))
# ax.bar(x, y, color='steelblue', alpha=0.7)
# ax.set_title('[Título]', fontsize=14, fontweight='bold')
# plt.tight_layout()
# plt.show()

print("✅ Visualización completada")

# %% [markdown]
# ---
#
# # 📤 SECCIONES FINALES (obligatorias)
#
# > Las siguientes secciones deben aparecer al final de todo notebook:
#
# ---
#
# ## 💾 Exportar resultados
#
# **Formato recomendado:** Parquet (columnar, comprimido) o CSV según caso de uso

# %%
# Exportar resultados
processed_path = root / 'data' / 'processed' / '[carpeta_notebook_id]'
processed_path.mkdir(parents=True, exist_ok=True)

# df.to_parquet(processed_path / 'resultado.parquet', index=False)
# df.to_csv(processed_path / 'resultado.csv', index=False)

print(f"✅ Resultados exportados a {processed_path}")

# %% [markdown]
# ---
#
# ## ✅ Validaciones

# %%
# Validaciones de integridad y lógica de negocio
# assert condicion_1, "Mensaje de error si falla"
# assert condicion_2, "Mensaje de error si falla"
# assert df['columna'].notna().all(), "No deben existir valores nulos"
# assert df['metrica'].min() >= 0, "La métrica debe ser no negativa"

print("✅ Validaciones pasadas")
print("✅ Notebook [ID] completado: [Descripción breve del resultado]")

# %% [markdown]
# ---
#
# ## 📚 Resumen Técnico y Referencias
#
#
#
# ### 🎯 Resultados Clave
#
# Este análisis implementa [descripción breve de lo implementado].
#
# **Componentes/Métricas calculadas:**
# 1. **[Componente 1]**: [Descripción y fórmula]
# 2. **[Componente 2]**: [Descripción y fórmula]
# 3. **[Componente 3]**: [Descripción y fórmula]
#
# **Hallazgos típicos:**
# - [Hallazgo 1]
# - [Hallazgo 2]
# - [Hallazgo 3]
#
# **Segmentación/Clasificación (si aplica):**
# - **[Segmento 1]**: [Descripción] → [Acción recomendada]
# - **[Segmento 2]**: [Descripción] → [Acción recomendada]
#
# ### 🔬 Metodología
#
# **Modelo/Fórmula principal:**
#
# $$
# \text{[Métrica Principal]} = [Fórmula en LaTeX]
# $$
#
# $$
# \text{[Métrica Secundaria]} = [Fórmula en LaTeX]
# $$
#
# **Técnica aplicada:**
# - [Descripción de la técnica/algoritmo utilizado]
# - Parámetros: [Parámetros configurados]
#
# ### 📖 Aplicaciones Prácticas
#
# 1. **[Aplicación 1]:**
#    - [Detalle de cómo aplicar en la práctica]
#
# 2. **[Aplicación 2]:**
#    - [Detalle de cómo aplicar en la práctica]
#
# 3. **[Aplicación 3]:**
#    - [Detalle de cómo aplicar en la práctica]
#
# ### 🔗 Referencias
#
# 1. **[Autor(es), Año]**. *[Título del artículo/libro]*. [Publicación/Editorial].
#    - [Relevancia para el notebook]
#
# 2. **[Autor(es), Año]**. *[Título del artículo/libro]*. [Publicación/Editorial].
#    - [Relevancia para el notebook]
#
# 3. **[Autor(es), Año]**. *[Título del artículo/libro]*. [Publicación/Editorial].
#    - [Relevancia para el notebook]
#
# ### 💡 Extensiones Futuras
#
# - [Extensión posible 1]
# - [Extensión posible 2]
# - [Extensión posible 3]
# - [Extensión posible 4]
#
# ---
#
# **Autor**: lraigosov (@LuisRai)
# **Fecha**: [año] a la actualidad
# **Versión**: 1.0
# **Tags**: `#[tag1]` `#[tag2]` `#[tag3]` `#[tag4]`
#
# ---

# %% [markdown]
# <div style="width: 100%; clear: both; margin: 0 0 20px 0; border-top: 1px solid #eaecef; padding-top: 24px;"><div style="display: flex; justify-content: space-between; align-items: center; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif;"><div style="flex: 1; text-align: left;"><a href="[notebook_anterior].ipynb" style="text-decoration: none; color: #0366d6; font-size: 14px; font-weight: 600; transition: color 0.2s;">← Anterior: [XX-##-nombre_anterior.ipynb]</a></div><div style="flex: 1; text-align: center; font-size: 14px;"><a href="../../README.md" style="color: #0366d6; text-decoration: none; font-weight: 600; margin: 0 10px;">📑 Índice</a><span style="color: #6a737d;">|</span><a href="../../config/notebooks_index.yml" style="color: #0366d6; text-decoration: none; font-weight: 600; margin: 0 10px;">📋 Catálogo</a></div><div style="flex: 1; text-align: right;"><a href="[notebook_siguiente].ipynb" style="text-decoration: none; color: #0366d6; font-size: 14px; font-weight: 600; transition: color 0.2s;">Siguiente: [XX-##] →</a></div></div></div>
